# %% [markdown]
# # Scaling

# %% [markdown]
# ## Import

# %%
pip install mglearn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import mglearn

plt.rc('figure', figsize=(10, 6))

from matplotlib import rcParams
rcParams['font.family'] = 'DejaVu Sans'
rcParams['font.size'] = 10
rcParams['axes.unicode_minus'] = False

# %% [markdown]
# - Feature(X값): 수치형 데이터
# - [scikit-learn preprocessing](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing)

# %% [markdown]
# ##Contents
# 1. Standard Scaling
# 2. MinMax Scaling
# 3. Robust Scaling
# 4. Normalization Scaling
# 5. Log Scaling
# 6. Exponential Scaling

# %%
mglearn.plots.plot_scaling()

# %% [markdown]
# ## Preparation

# %% [markdown]
# #### 데이터 로딩

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()

# %% [markdown]
# #### 데이터 분할: 학습 데이터 + 테스트 데이터

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=123)
print(X_train.shape)
print(X_test.shape)
# Out:
# (426, 30)
# (143, 30)

# %% [markdown]
# ## Standard Scaling

# %% [markdown]
# ### 스케일러 생성

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [markdown]
# ### 스케일러 학습 - 규칙 설정

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %% [markdown]
# ### 학습 데이터 변환

# %%
X_train_scaled = scaler.transform(X_train)

# %%
print('변환된 후 크기:', X_train_scaled.shape)
print('스케일 조정 전 특성별 최소값:\n', X_train.min(axis=0))
print('스케일 조정 전 특성별 최대값:\n', X_train.max(axis=0))
print('스케일 조정 후 특성별 최소값:\n', X_train_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_train_scaled.max(axis=0))
# Out:
# 변환된 후 크기: (426, 30)
# 스케일 조정 전 특성별 최소값:
#  [6.981e+00 1.038e+01 4.379e+01 1.435e+02 5.263e-02 2.650e-02 0.000e+00
#  0.000e+00 1.060e-01 4.996e-02 1.115e-01 3.602e-01 7.570e-01 6.802e+00
#  2.667e-03 3.012e-03 0.000e+00 0.000e+00 7.882e-03 8.948e-04 7.930e+00
#  1.249e+01 5.041e+01 1.852e+02 8.409e-02 4.327e-02 0.000e+00 0.000e+00
#  1.565e-01 5.504e-02]
# 스케일 조정 전 특성별 최대값:
#  [2.742e+01 3.928e+01 1.869e+02 2.501e+03 1.634e-01 3.454e-01 4.268e-01
#  2.012e-01 3.040e-01 9.744e-02 2.547e+00 3.896e+00 1.865e+01 5.422e+02
#  3.113e-02 1.064e-01 3.960e-01 5.279e-02 7.895e-02 2.984e-02 3.604e+01
#  4.954e+01 2.512e+02 4.254e+03 2.226e-01 9.379e-01 1.252e+00 2.910e-01
#  6.638e-01 1.730e-01]
# 스케일 조정 후 특성별 최소값:
#  [-2.02922184 -2.02920251 -1.98977696 -1.4754887  -3.096654   -1.49048106
#  -1.12282697 -1.27880749 -2.63203019 -1.74699992 -1.12516064 -1.59991069
#  -1.11002401 -0.79210374 -1.43410805 -1.28314336 -1.01443755 -1.89138942
#  -1.54265395 -1.06773073 -1.72306595 -2.10560959 -1.69146265 -1.22315935
#  -2.0918382  -1.38959295 -1.31956005 -1.76037681 -2.10581091 -1.66044303]
# 스케일 조정 후 특성별 최대값:
#  [ 3.73948826  4.48650331  3.8818278   5.27595264  4.71903272  4.48880385
#   4.17940851  3.88709036  4.24146961  4.62460723  8.04381356  4.87312911
#   8.12911628 11.74874228  7.7782182   4.42023505 11.14027764  6.3075606
#   6.93410846  9.20831152  4.06305618  3.7937004   4.25123722  5.90602867
#   3.98332807  4.50183188  4.74985037  2.66975402  5.95623512  5.16954782]

# %% [markdown]
# #### 1.1.4 테스트 데이터 변환

# %%
X_test_scaled = scaler.transform(X_test)

# %%
print('스케일 조정 후 특성별 최소값:\n', X_test_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_test_scaled.max(axis=0))
# Out:
# 스케일 조정 후 특성별 최소값:
#  [-1.67980831 -2.18025867 -1.60082571 -1.30251434 -2.399543   -1.62397905
#  -1.12282697 -1.27880749 -1.67043451 -1.66916647 -1.11424295 -1.59643234
#  -1.1025885  -0.77982987 -1.74287941 -1.32506861 -1.01443755 -1.89138942
#  -1.34501232 -1.04806278 -1.51269893 -2.18044564 -1.50677991 -1.12696578
#  -2.65852038 -1.49482637 -1.31956005 -1.76037681 -1.97390674 -1.64828384]
# 스케일 조정 후 특성별 최대값:
#  [ 3.93423409  2.23418839  3.94747358  5.27022501  2.2071753   3.00945114
#   3.25387772  3.45831057  2.50573734  2.63448646  9.2711121   6.68370561
#   9.84857848 11.3599137   4.41863044  6.02001427  2.56445081  2.45891537
#   4.84795752  2.99196132  3.02768818  2.38296122  3.0821718   3.95937907
#   2.43504008  5.29272881  4.0372279   2.6042916   3.61692273  7.16712907]

# %% [markdown]
# ## MinMaxScaler

# %% [markdown]
# ### 스케일러 생성

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %% [markdown]
# ### 스케일러 학습 - 규칙 설정

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %% [markdown]
# ### 학습 데이터 변환

# %%
X_train_scaled = scaler.transform(X_train)

# %%
print('변환된 후 크기:', X_train_scaled.shape)
print('스케일 조정 전 특성별 최소값:\n', X_train.min(axis=0))
print('스케일 조정 전 특성별 최대값:\n', X_train.max(axis=0))
print('스케일 조정 후 특성별 최소값:\n', X_train_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_train_scaled.max(axis=0))

# %% [markdown]
# min-max scaling은 0~1사이 값으로 바꿔주는 건데, 결과값이 1보다 큰게 있다?
# train 데이터의 최댓값보다 큰 값이 test 데이터에 있는 경우가 그렇다.

# %% [markdown]
# #### 1.2.4 테스트 데이터 변환

# %%
X_test_scaled = scaler.transform(X_test)

# %%
print('스케일 조정 후 특성별 최소값:\n', X_test_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_test_scaled.max(axis=0))

# %% [markdown]
# ## RobustScaler

# %% [markdown]
# ### 스케일러 생성

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()

# %% [markdown]
# ### 스케일러 학습 - 규칙 설정

# %%
scaler.fit(X_train)
# Out:
# RobustScaler()

# %% [markdown]
# ### 학습 데이터 변환

# %%
X_train_scaled = scaler.transform(X_train)

# %%
print('변환된 후 크기:', X_train_scaled.shape)
print('스케일 조정 전 특성별 최소값:\n', X_train.min(axis=0))
print('스케일 조정 전 특성별 최대값:\n', X_train.max(axis=0))
print('스케일 조정 후 특성별 최소값:\n', X_train_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_train_scaled.max(axis=0))

# %% [markdown]
# ### 테스트 데이터 변환

# %%
X_test_scaled = scaler.transform(X_test)

# %%
print('스케일 조정 후 특성별 최소값:\n', X_test_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_test_scaled.max(axis=0))

# %% [markdown]
# ## Normalizer

# %% [markdown]
# ### 스케일러 생성

# %%
from sklearn.preprocessing import Normalizer
scaler = Normalizer()

# %% [markdown]
# ### 스케일러 학습 - 규칙 설정

# %%
scaler.fit(X_train)
# Out:
# Normalizer()

# %% [markdown]
# ### 학습 데이터 변환

# %%
X_train_scaled = scaler.transform(X_train)

# %%
print('변환된 후 크기:', X_train_scaled.shape)
print('스케일 조정 전 특성별 최소값:\n', X_train.min(axis=0))
print('스케일 조정 전 특성별 최대값:\n', X_train.max(axis=0))
print('스케일 조정 후 특성별 최소값:\n', X_train_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_train_scaled.max(axis=0))

# %% [markdown]
# ### 테스트 데이터 변환

# %%
X_test_scaled = scaler.transform(X_test)

# %%
print('스케일 조정 후 특성별 최소값:\n', X_test_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_test_scaled.max(axis=0))

# %% [markdown]
# ## Log  Scaling

# %% [markdown]
# ### 스케일러 생성

# %%
from sklearn.preprocessing import FunctionTransformer
scaler = FunctionTransformer(np.log1p)

# %% [markdown]
# ### 스케일러 학습 - 규칙 설정

# %%
scaler.fit(X_train)
# Out:
# FunctionTransformer(func=<ufunc 'log1p'>)

# %% [markdown]
# ### 학습 데이터 변환

# %%
X_train_scaled = scaler.transform(X_train)

# %%
print('변환된 후 크기:', X_train_scaled.shape)
print('스케일 조정 전 특성별 최소값:\n', X_train.min(axis=0))
print('스케일 조정 전 특성별 최대값:\n', X_train.max(axis=0))
print('스케일 조정 후 특성별 최소값:\n', X_train_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_train_scaled.max(axis=0))

# %% [markdown]
# ### 테스트 데이터 변환

# %%
X_test_scaled = scaler.transform(X_test)

# %%
print('스케일 조정 후 특성별 최소값:\n', X_test_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_test_scaled.max(axis=0))

# %% [markdown]
# ## Exponential Scaling

# %% [markdown]
# ### 스케일러 생성

# %%
from sklearn.preprocessing import FunctionTransformer
scaler = FunctionTransformer(np.expm1)

# %% [markdown]
# ### 스케일러 학습 - 규칙 설정

# %%
scaler.fit(X_train)
# Out:
# FunctionTransformer(func=<ufunc 'expm1'>)

# %% [markdown]
# ### 학습 데이터 변환

# %%
X_train_scaled = scaler.transform(X_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_function_transformer.py:310: RuntimeWarning: overflow encountered in expm1
#   return func(X, **(kw_args if kw_args else {}))

# %%
print('변환된 후 크기:', X_train_scaled.shape)
print('스케일 조정 전 특성별 최소값:\n', X_train.min(axis=0))
print('스케일 조정 전 특성별 최대값:\n', X_train.max(axis=0))
print('스케일 조정 후 특성별 최소값:\n', X_train_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_train_scaled.max(axis=0))

# %% [markdown]
# ### 테스트 데이터 변환

# %%
X_test_scaled = scaler.transform(X_test)

# %%
print('스케일 조정 후 특성별 최소값:\n', X_test_scaled.min(axis=0))
print('스케일 조정 후 특성별 최대값:\n', X_test_scaled.max(axis=0))

# %% [markdown]
# ## **Caution:**
# #### 학습 데이터와 테스트 데이터의 스케일 조정 관련
# * **fit을 통해 학습시키는 것은 x_train에서만 하고, x_test에서 또 하면 안된다.**
# * x_train 데이터를 통해 규칙을 찾아 scaling 했는데, x_test라는 새로운 환경에서는 새 규칙이 찾아지기 때문이다.
# * 따라서, x_train에서 fit 시켜서 규칙 만들고, 그 규칙을 통한 scale 변환은 x_train, x_test 둘 다 시켜주면 된다는 뜻.

# %%
# 데이터셋 생성
from sklearn.datasets import make_blobs
X, _ = make_blobs(n_samples=50, centers=5, random_state=4, cluster_std=2)

# 데이터 분할
X_train, X_test = train_test_split(X, random_state=123, test_size=0.1)

# plot 1: 원본 데이터
fig, axes = plt.subplots(1, 3, figsize=(13, 4))

axes[0].scatter(X_train[:, 0], X_train[:, 1], c=mglearn.cm2.colors[0], label='학습 세트', s=60)
axes[0].scatter(X_test[:, 0], X_test[:, 1], marker='^', c=mglearn.cm2.colors[1], label='테스트 세트', s=60)
axes[0].legend(loc='upper left')
axes[0].set_title('원본 데이터')

#
# plot 2: 스케일 조정된 데이터
#

# MinMaxScaler를 사용해 스케일을 조정합니다
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

axes[1].scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=mglearn.cm2.colors[0], label='학습 세트', s=60)
axes[1].scatter(X_test_scaled[:, 0], X_test_scaled[:, 1], marker='^', c=mglearn.cm2.colors[1], label='테스트 세트', s=60)
axes[1].set_title('스케일 조정된 데이터')

#
# plot 3: 잘못 조정된 데이터
#
# 잘못된 스케일 조정: 테스트 세트의 스케일을 따로 조정합니다
test_scaler = MinMaxScaler()
test_scaler.fit(X_test)

X_test_scaled_badly = test_scaler.transform(X_test)

axes[2].scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=mglearn.cm2.colors[0], label='학습 세트', s=60)
axes[2].scatter(X_test_scaled_badly[:, 0], X_test_scaled_badly[:, 1], marker='^', c=mglearn.cm2.colors[1], label='테스트 세트', s=60)
axes[2].set_title('잘못 조정된 데이터')

for ax in axes:
    ax.set_xlabel("특성 0")
    ax.set_ylabel("특성 1")
fig.tight_layout()

plt.show()

# %% [markdown]
# ## Example: Standard Scaling - Model: SVM

# %% [markdown]
# ### 데이터 분할

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=123)

# %% [markdown]
# ### Model: Supprt Vector Machine

# %%
from sklearn.svm import SVC

svm = SVC(gamma='auto')

svm.fit(X_train, y_train)

print('테스트 세트 정확도: {:.2f}'.format(svm.score(X_test, y_test)))
# Out:
# 테스트 세트 정확도: 0.62

# %% [markdown]
# ### SVM with StandardScaled Data

# %%
# StandardScaler: 평균 0, 분산 1을 갖도록 스케일 조정
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 조정된 데이터로 SVM 학습
svm.fit(X_train_scaled, y_train)

# 스케일 조정된 테스트 세트의 정확도
print('스케일 조정된 테스트 세트의 정확도(StandardScaler): {:.2f}'.format(svm.score(X_test_scaled, y_test)))
# Out:
# 스케일 조정된 테스트 세트의 정확도(StandardScaler): 0.99

# %% [markdown]
# ### SVM with MinMaxScaled Data

# %%
# MinMaxScaler: 0~1 사이로 스케일 조정
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 조정된 데이터로 SVM 학습
svm.fit(X_train_scaled, y_train)

# 스케일 조정된 테스트 세트의 정확도
print('스케일 조정된 테스트 세트의 정확도(MinMaxScaler): {:.2f}'.format(svm.score(X_test_scaled, y_test)))
# Out:
# 스케일 조정된 테스트 세트의 정확도(MinMaxScaler): 0.97

# %% [markdown]
# ## Example: Log Scailing - Model: Ridge

# %% [markdown]
# ### 데이터 생성

# %%
rnd = np.random.RandomState(123)
X_org = rnd.normal(size=(1000, 3))
w = rnd.normal(size=3)

X = rnd.poisson(10 * np.exp(X_org))
y = np.dot(X_org, w)
X
# Out:
# array([[ 4, 34, 15],
#        [ 5,  9, 58],
#        [ 0,  5, 47],
#        ...,
#        [ 4, 14, 11],
#        [ 5, 10,  5],
#        [77, 23,  2]])

# %% [markdown]
# ### 데이터 분포 - 히스토그램

# %%
plt.hist(X[:, 0], bins=25)
plt.ylabel("출현 횟수")
plt.xlabel("값")
plt.show()

# %% [markdown]
# ### Model: Ridge

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123)

from sklearn.linear_model import Ridge
score = Ridge().fit(X_train, y_train).score(X_test, y_test)
score
# Out:
# 0.6250959429749785

# %% [markdown]
# ### 로그 스케일링 적용

# %%
X_train_log = np.log1p(X_train)
X_test_log = np.log1p(X_test)

# %% [markdown]
# ### 로그 스케일링 적용된 데이터 분포 - 히스토그램

# %%
plt.hist(X_train_log[:, 0], bins=25)
plt.ylabel("출현 횟수")
plt.xlabel("값")
plt.show()

# %% [markdown]
# ### Ridge 알고리즘 학습 및 평가 - 로그 스케일링 적용

# %%
score = Ridge().fit(X_train_log, y_train).score(X_test_log, y_test)
score
# Out:
# 0.85368520133628
